# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

from config import weather_api_key

# Import the requests library.
import requests

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
coordinates = lat_lngs

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 612

# %%
# Import the API key.
from config import weather_api_key

# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

#loop through cities in list
for i, city in enumerate(cities):
    
    #group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    #create URL endpoint for city
    city_url = url + '&q=' + city.replace(" ","+")
    
    #log the URL, record, and set numbers and the city
    print(f'Processing Record {record_count} of Set {set_count} | {city}')
    # add 1 to record count
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_weather_dc = city_weather["weather"][0]["description"]
       
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_weather_dc})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | sataua
# City not found. Skipping...
# Processing Record 2 of Set 1 | bara
# Processing Record 3 of Set 1 | the valley
# Processing Record 4 of Set 1 | cidreira
# Processing Record 5 of Set 1 | dikson
# Processing Record 6 of Set 1 | saint-pierre
# Processing Record 7 of Set 1 | jamestown
# Processing Record 8 of Set 1 | castro
# Processing Record 9 of Set 1 | port elizabeth
# Processing Record 10 of Set 1 | saint-philippe
# Processing Record 11 of Set 1 | airai
# Processing Record 12 of Set 1 | puerto baquerizo moreno
# Processing Record 13 of Set 1 | busselton
# Processing Record 14 of Set 1 | ciulnita
# Processing Record 15 of Set 1 | grindavik
# Processing Record 16 of Set 1 | college
# Processing Record 17 of Set 1 | fortuna
# Processing Record 18 of Set 1 | upernavik
# Processing Record 19 of Set 1 | mataura
# Processing Record 20 of Set 1 | butaritari
# Processing Record 21 of Set 1 | henties bay
# Processing Record 22 of Set 1 | cheremukhovo
# Processing Record 23 of Set 1 | barrow
# Processing Record 24 of Set 1 | ushuaia
# Processing Record 25 of Set 1 | punta arenas
# Processing Record 26 of Set 1 | luanda
# Processing Record 27 of Set 1 | marsa matruh
# Processing Record 28 of Set 1 | east london
# Processing Record 29 of Set 1 | ancud
# Processing Record 30 of Set 1 | albany
# Processing Record 31 of Set 1 | cherskiy
# Processing Record 32 of Set 1 | lamu
# Processing Record 33 of Set 1 | kodinsk
# Processing Record 34 of Set 1 | talnakh
# Processing Record 35 of Set 1 | san policarpo
# Processing Record 36 of Set 1 | tumannyy
# City not found. Skipping...
# Processing Record 37 of Set 1 | bethel
# Processing Record 38 of Set 1 | paamiut
# Processing Record 39 of Set 1 | provideniya
# Processing Record 40 of Set 1 | georgetown
# Processing Record 41 of Set 1 | yellowknife
# Processing Record 42 of Set 1 | ribeira grande
# Processing Record 43 of Set 1 | corsicana
# Processing Record 44 of Set 1 | qaanaaq
# Processing Record 45 of Set 1 | avarua
# Processing Record 46 of Set 1 | ilulissat
# Processing Record 47 of Set 1 | rennes
# Processing Record 48 of Set 1 | tura
# Processing Record 49 of Set 1 | irbeyskoye
# Processing Record 50 of Set 1 | kazachinskoye
# Processing Record 1 of Set 2 | sangar
# Processing Record 2 of Set 2 | mahebourg
# Processing Record 3 of Set 2 | cape town
# Processing Record 4 of Set 2 | touros
# Processing Record 5 of Set 2 | kodiak
# Processing Record 6 of Set 2 | doka
# Processing Record 7 of Set 2 | hobart
# Processing Record 8 of Set 2 | isangel
# Processing Record 9 of Set 2 | kapaa
# Processing Record 10 of Set 2 | wanning
# Processing Record 11 of Set 2 | mar del plata
# Processing Record 12 of Set 2 | bluff
# Processing Record 13 of Set 2 | hermanus
# Processing Record 14 of Set 2 | kasaragod
# Processing Record 15 of Set 2 | ostrovnoy
# Processing Record 16 of Set 2 | rikitea
# Processing Record 17 of Set 2 | srandakan
# Processing Record 18 of Set 2 | tuktoyaktuk
# Processing Record 19 of Set 2 | puerto ayora
# Processing Record 20 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 21 of Set 2 | olafsvik
# Processing Record 22 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 23 of Set 2 | mazagao
# Processing Record 24 of Set 2 | ziebice
# Processing Record 25 of Set 2 | jalu
# Processing Record 26 of Set 2 | hithadhoo
# Processing Record 27 of Set 2 | thompson
# Processing Record 28 of Set 2 | chumikan
# Processing Record 29 of Set 2 | cabo san lucas
# Processing Record 30 of Set 2 | solovetskiy
# City not found. Skipping...
# Processing Record 31 of Set 2 | nuuk
# Processing Record 32 of Set 2 | natal
# Processing Record 33 of Set 2 | banjar
# Processing Record 34 of Set 2 | nikolskoye
# Processing Record 35 of Set 2 | raudeberg
# Processing Record 36 of Set 2 | teya
# Processing Record 37 of Set 2 | port alfred
# Processing Record 38 of Set 2 | toliary
# City not found. Skipping...
# Processing Record 39 of Set 2 | carutapera
# Processing Record 40 of Set 2 | mount isa
# Processing Record 41 of Set 2 | narsaq
# Processing Record 42 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 43 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 44 of Set 2 | vardo
# Processing Record 45 of Set 2 | gobabis
# Processing Record 46 of Set 2 | bredasdorp
# Processing Record 47 of Set 2 | camacha
# Processing Record 48 of Set 2 | fort nelson
# Processing Record 49 of Set 2 | makokou
# Processing Record 50 of Set 2 | vangaindrano
# Processing Record 1 of Set 3 | ayagoz
# Processing Record 2 of Set 3 | moose factory
# Processing Record 3 of Set 3 | kargil
# Processing Record 4 of Set 3 | leningradskiy
# Processing Record 5 of Set 3 | parkes
# Processing Record 6 of Set 3 | saint-francois
# Processing Record 7 of Set 3 | necochea
# Processing Record 8 of Set 3 | port hardy
# Processing Record 9 of Set 3 | sulgen
# Processing Record 10 of Set 3 | vaini
# Processing Record 11 of Set 3 | sept-iles
# Processing Record 12 of Set 3 | sur
# Processing Record 13 of Set 3 | hvide sande
# Processing Record 14 of Set 3 | lompoc
# Processing Record 15 of Set 3 | kushmurun
# Processing Record 16 of Set 3 | namibe
# Processing Record 17 of Set 3 | lata
# Processing Record 18 of Set 3 | yanchukan
# City not found. Skipping...
# Processing Record 19 of Set 3 | kalabo
# Processing Record 20 of Set 3 | lasa
# Processing Record 21 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 22 of Set 3 | kardzhin
# Processing Record 23 of Set 3 | faanui
# Processing Record 24 of Set 3 | luyang
# Processing Record 25 of Set 3 | sinnamary
# Processing Record 26 of Set 3 | sosnogorsk
# Processing Record 27 of Set 3 | tiksi
# Processing Record 28 of Set 3 | ouango
# Processing Record 29 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 30 of Set 3 | khatanga
# Processing Record 31 of Set 3 | rocha
# Processing Record 32 of Set 3 | bengkulu
# Processing Record 33 of Set 3 | norman wells
# Processing Record 34 of Set 3 | ponta do sol
# Processing Record 35 of Set 3 | saldanha
# Processing Record 36 of Set 3 | homer
# Processing Record 37 of Set 3 | sug-aksy
# City not found. Skipping...
# Processing Record 38 of Set 3 | skibbereen
# Processing Record 39 of Set 3 | tazovskiy
# Processing Record 40 of Set 3 | quatre cocos
# Processing Record 41 of Set 3 | sovetskiy
# Processing Record 42 of Set 3 | sola
# Processing Record 43 of Set 3 | pisco
# Processing Record 44 of Set 3 | auki
# Processing Record 45 of Set 3 | charlottetown
# Processing Record 46 of Set 3 | uk
# City not found. Skipping...
# Processing Record 47 of Set 3 | pano aqil
# Processing Record 48 of Set 3 | churapcha
# Processing Record 49 of Set 3 | saurimo
# Processing Record 50 of Set 3 | boyolangu
# Processing Record 1 of Set 4 | lebu
# Processing Record 2 of Set 4 | yerazgavors
# Processing Record 3 of Set 4 | sande
# Processing Record 4 of Set 4 | ahipara
# Processing Record 5 of Set 4 | lufilufi
# Processing Record 6 of Set 4 | beyneu
# Processing Record 7 of Set 4 | lagoa
# Processing Record 8 of Set 4 | oranjemund
# Processing Record 9 of Set 4 | hilo
# Processing Record 10 of Set 4 | alofi
# Processing Record 11 of Set 4 | charcas
# Processing Record 12 of Set 4 | kota kinabalu
# Processing Record 13 of Set 4 | tasiilaq
# Processing Record 14 of Set 4 | atuona
# Processing Record 15 of Set 4 | renfrew
# Processing Record 16 of Set 4 | paita
# Processing Record 17 of Set 4 | saskylakh
# Processing Record 18 of Set 4 | cockburn town
# Processing Record 19 of Set 4 | svetlaya
# Processing Record 20 of Set 4 | arcachon
# Processing Record 21 of Set 4 | nanortalik
# Processing Record 22 of Set 4 | pemangkat
# Processing Record 23 of Set 4 | vila velha
# Processing Record 24 of Set 4 | esperance
# Processing Record 25 of Set 4 | fairbanks
# Processing Record 26 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 27 of Set 4 | bucerias
# Processing Record 28 of Set 4 | caucaguita
# Processing Record 29 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 30 of Set 4 | labutta
# City not found. Skipping...
# Processing Record 31 of Set 4 | mabaruma
# Processing Record 32 of Set 4 | guerrero negro
# Processing Record 33 of Set 4 | comodoro rivadavia
# Processing Record 34 of Set 4 | kamaishi
# Processing Record 35 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 36 of Set 4 | kholbon
# Processing Record 37 of Set 4 | tucupita
# Processing Record 38 of Set 4 | komsomolskiy
# Processing Record 39 of Set 4 | constitucion
# Processing Record 40 of Set 4 | burley
# Processing Record 41 of Set 4 | kyshtovka
# Processing Record 42 of Set 4 | epe
# Processing Record 43 of Set 4 | porto-vecchio
# Processing Record 44 of Set 4 | medeiros neto
# Processing Record 45 of Set 4 | shieli
# Processing Record 46 of Set 4 | torbay
# Processing Record 47 of Set 4 | male
# Processing Record 48 of Set 4 | halalo
# City not found. Skipping...
# Processing Record 49 of Set 4 | orocue
# Processing Record 50 of Set 4 | brigantine
# Processing Record 1 of Set 5 | new norfolk
# Processing Record 2 of Set 5 | finschhafen
# Processing Record 3 of Set 5 | muzhi
# Processing Record 4 of Set 5 | bac can
# City not found. Skipping...
# Processing Record 5 of Set 5 | acapulco
# Processing Record 6 of Set 5 | severo-kurilsk
# Processing Record 7 of Set 5 | pauini
# Processing Record 8 of Set 5 | salalah
# Processing Record 9 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 10 of Set 5 | hovd
# Processing Record 11 of Set 5 | aguimes
# Processing Record 12 of Set 5 | pevek
# Processing Record 13 of Set 5 | strezhevoy
# Processing Record 14 of Set 5 | solnechnyy
# Processing Record 15 of Set 5 | bodden town
# Processing Record 16 of Set 5 | poum
# Processing Record 17 of Set 5 | witu
# Processing Record 18 of Set 5 | portland
# Processing Record 19 of Set 5 | kaitangata
# Processing Record 20 of Set 5 | san cristobal
# Processing Record 21 of Set 5 | yumen
# Processing Record 22 of Set 5 | borba
# Processing Record 23 of Set 5 | carnarvon
# Processing Record 24 of Set 5 | chuy
# Processing Record 25 of Set 5 | rungata
# City not found. Skipping...
# Processing Record 26 of Set 5 | senador jose porfirio
# Processing Record 27 of Set 5 | paradwip
# City not found. Skipping...
# Processing Record 28 of Set 5 | marawi
# Processing Record 29 of Set 5 | jati
# Processing Record 30 of Set 5 | bayan
# Processing Record 31 of Set 5 | gazimurskiy zavod
# Processing Record 32 of Set 5 | oussouye
# Processing Record 33 of Set 5 | sao joao da barra
# Processing Record 34 of Set 5 | tambopata
# Processing Record 35 of Set 5 | pilar
# Processing Record 36 of Set 5 | nome
# Processing Record 37 of Set 5 | dakar
# Processing Record 38 of Set 5 | mareeba
# Processing Record 39 of Set 5 | ulaanbaatar
# Processing Record 40 of Set 5 | sault sainte marie
# Processing Record 41 of Set 5 | san quintin
# Processing Record 42 of Set 5 | hasaki
# Processing Record 43 of Set 5 | camana
# Processing Record 44 of Set 5 | eyl
# Processing Record 45 of Set 5 | katsuura
# Processing Record 46 of Set 5 | tuatapere
# Processing Record 47 of Set 5 | atambua
# Processing Record 48 of Set 5 | omboue
# Processing Record 49 of Set 5 | tessalit
# Processing Record 50 of Set 5 | riyadh
# Processing Record 1 of Set 6 | kracheh
# City not found. Skipping...
# Processing Record 2 of Set 6 | cayenne
# Processing Record 3 of Set 6 | tahoua
# Processing Record 4 of Set 6 | tanout
# Processing Record 5 of Set 6 | usinsk
# Processing Record 6 of Set 6 | mitchell
# Processing Record 7 of Set 6 | piacabucu
# Processing Record 8 of Set 6 | cape canaveral
# Processing Record 9 of Set 6 | capinota
# Processing Record 10 of Set 6 | santa isabel
# Processing Record 11 of Set 6 | buqayq
# City not found. Skipping...
# Processing Record 12 of Set 6 | orodara
# Processing Record 13 of Set 6 | nan
# Processing Record 14 of Set 6 | umm kaddadah
# Processing Record 15 of Set 6 | imbituba
# Processing Record 16 of Set 6 | westport
# Processing Record 17 of Set 6 | choa saidan shah
# Processing Record 18 of Set 6 | coahuayana
# Processing Record 19 of Set 6 | vila franca do campo
# Processing Record 20 of Set 6 | santo antonio do sudoeste
# Processing Record 21 of Set 6 | bur gabo
# City not found. Skipping...
# Processing Record 22 of Set 6 | vostok
# Processing Record 23 of Set 6 | mwense
# Processing Record 24 of Set 6 | progreso
# Processing Record 25 of Set 6 | sao jose da coroa grande
# Processing Record 26 of Set 6 | helena
# Processing Record 27 of Set 6 | garden city
# Processing Record 28 of Set 6 | karratha
# Processing Record 29 of Set 6 | nosy varika
# Processing Record 30 of Set 6 | kontagora
# Processing Record 31 of Set 6 | saint george
# Processing Record 32 of Set 6 | ascension
# Processing Record 33 of Set 6 | arraial do cabo
# Processing Record 34 of Set 6 | rawson
# Processing Record 35 of Set 6 | olinda
# Processing Record 36 of Set 6 | jacqueville
# Processing Record 37 of Set 6 | mehamn
# Processing Record 38 of Set 6 | warqla
# City not found. Skipping...
# Processing Record 39 of Set 6 | mackenzie
# Processing Record 40 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 41 of Set 6 | north bend
# Processing Record 42 of Set 6 | kavaratti
# Processing Record 43 of Set 6 | ulladulla
# Processing Record 44 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 45 of Set 6 | tromso
# Processing Record 46 of Set 6 | walvis bay
# Processing Record 47 of Set 6 | keffi
# Processing Record 48 of Set 6 | alta floresta
# Processing Record 49 of Set 6 | bogo
# Processing Record 50 of Set 6 | port-cartier
# Processing Record 1 of Set 7 | katobu
# Processing Record 2 of Set 7 | gamarra
# Processing Record 3 of Set 7 | san patricio
# Processing Record 4 of Set 7 | ayios kirikos
# City not found. Skipping...
# Processing Record 5 of Set 7 | klaksvik
# Processing Record 6 of Set 7 | port blair
# Processing Record 7 of Set 7 | carbonia
# Processing Record 8 of Set 7 | inirida
# Processing Record 9 of Set 7 | urzhum
# Processing Record 10 of Set 7 | tsihombe
# City not found. Skipping...
# Processing Record 11 of Set 7 | katangli
# Processing Record 12 of Set 7 | filingue
# Processing Record 13 of Set 7 | bonavista
# Processing Record 14 of Set 7 | baruun-urt
# Processing Record 15 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 16 of Set 7 | maine-soroa
# Processing Record 17 of Set 7 | langenburg
# Processing Record 18 of Set 7 | aklavik
# Processing Record 19 of Set 7 | amberley
# Processing Record 20 of Set 7 | kopervik
# Processing Record 21 of Set 7 | almaznyy
# Processing Record 22 of Set 7 | lar gerd
# City not found. Skipping...
# Processing Record 23 of Set 7 | vao
# Processing Record 24 of Set 7 | naze
# Processing Record 25 of Set 7 | flin flon
# Processing Record 26 of Set 7 | havoysund
# Processing Record 27 of Set 7 | ahuimanu
# Processing Record 28 of Set 7 | amalapuram
# Processing Record 29 of Set 7 | changping
# Processing Record 30 of Set 7 | nouadhibou
# Processing Record 31 of Set 7 | dicabisagan
# Processing Record 32 of Set 7 | hami
# Processing Record 33 of Set 7 | pilao arcado
# City not found. Skipping...
# Processing Record 34 of Set 7 | chokurdakh
# Processing Record 35 of Set 7 | victoria
# Processing Record 36 of Set 7 | oistins
# Processing Record 37 of Set 7 | ram das
# Processing Record 38 of Set 7 | durazno
# Processing Record 39 of Set 7 | port hedland
# Processing Record 40 of Set 7 | caravelas
# Processing Record 41 of Set 7 | samusu
# City not found. Skipping...
# Processing Record 42 of Set 7 | porec
# Processing Record 43 of Set 7 | asau
# Processing Record 44 of Set 7 | antofagasta
# Processing Record 45 of Set 7 | nsanje
# Processing Record 46 of Set 7 | nioro
# Processing Record 47 of Set 7 | porto novo
# Processing Record 48 of Set 7 | qandala
# Processing Record 49 of Set 7 | praia
# Processing Record 50 of Set 7 | egvekinot
# Processing Record 1 of Set 8 | marzuq
# Processing Record 2 of Set 8 | kusye-aleksandrovskiy
# City not found. Skipping...
# Processing Record 3 of Set 8 | broome
# Processing Record 4 of Set 8 | luderitz
# Processing Record 5 of Set 8 | arman
# Processing Record 6 of Set 8 | bar-le-duc
# Processing Record 7 of Set 8 | maldonado
# Processing Record 8 of Set 8 | mergui
# City not found. Skipping...
# Processing Record 9 of Set 8 | totma
# Processing Record 10 of Set 8 | mincivan
# Processing Record 11 of Set 8 | honiara
# Processing Record 12 of Set 8 | general pico
# Processing Record 13 of Set 8 | punta de piedra
# Processing Record 14 of Set 8 | mangan
# Processing Record 15 of Set 8 | zhigansk
# Processing Record 16 of Set 8 | bogotol
# Processing Record 17 of Set 8 | maxixe
# Processing Record 18 of Set 8 | santa rosa
# Processing Record 19 of Set 8 | ambon
# Processing Record 20 of Set 8 | copiapo
# Processing Record 21 of Set 8 | shumskiy
# Processing Record 22 of Set 8 | shenjiamen
# Processing Record 23 of Set 8 | bicholim
# Processing Record 24 of Set 8 | ambatondrazaka
# Processing Record 25 of Set 8 | la solana
# Processing Record 26 of Set 8 | korla
# Processing Record 27 of Set 8 | kamenka
# Processing Record 28 of Set 8 | crab hill
# City not found. Skipping...
# Processing Record 29 of Set 8 | smithers
# Processing Record 30 of Set 8 | saint anthony
# Processing Record 31 of Set 8 | kedrovyy
# Processing Record 32 of Set 8 | suluq
# Processing Record 33 of Set 8 | misratah
# Processing Record 34 of Set 8 | fort-shevchenko
# Processing Record 35 of Set 8 | iqaluit
# Processing Record 36 of Set 8 | miguel auza
# Processing Record 37 of Set 8 | peace river
# Processing Record 38 of Set 8 | nauta
# Processing Record 39 of Set 8 | anzhero-sudzhensk
# Processing Record 40 of Set 8 | bantry
# Processing Record 41 of Set 8 | husavik
# Processing Record 42 of Set 8 | dunedin
# Processing Record 43 of Set 8 | lorengau
# Processing Record 44 of Set 8 | samarai
# Processing Record 45 of Set 8 | tateyama
# Processing Record 46 of Set 8 | pangnirtung
# Processing Record 47 of Set 8 | atbasar
# Processing Record 48 of Set 8 | udachnyy
# Processing Record 49 of Set 8 | zolotinka
# City not found. Skipping...
# Processing Record 50 of Set 8 | teshie
# Processing Record 1 of Set 9 | grand gaube
# Processing Record 2 of Set 9 | bandarbeyla
# Processing Record 3 of Set 9 | bambous virieux
# Processing Record 4 of Set 9 | hirado
# Processing Record 5 of Set 9 | dondo
# Processing Record 6 of Set 9 | anadyr
# Processing Record 7 of Set 9 | tshikapa
# Processing Record 8 of Set 9 | awjilah
# Processing Record 9 of Set 9 | miri
# Processing Record 10 of Set 9 | lumeje
# Processing Record 11 of Set 9 | astoria
# Processing Record 12 of Set 9 | kunya
# Processing Record 13 of Set 9 | mentok
# City not found. Skipping...
# Processing Record 14 of Set 9 | petropavlovsk-kamchatskiy
# Processing Record 15 of Set 9 | phimai
# Processing Record 16 of Set 9 | tungkang
# City not found. Skipping...
# Processing Record 17 of Set 9 | matadi
# Processing Record 18 of Set 9 | xining
# Processing Record 19 of Set 9 | shuyskoye
# Processing Record 20 of Set 9 | yichang
# Processing Record 21 of Set 9 | nassau
# Processing Record 22 of Set 9 | milingimbi
# City not found. Skipping...
# Processing Record 23 of Set 9 | basoko
# Processing Record 24 of Set 9 | inyonga
# Processing Record 25 of Set 9 | coquimbo
# Processing Record 26 of Set 9 | naifaru
# Processing Record 27 of Set 9 | goderich
# Processing Record 28 of Set 9 | karakol
# Processing Record 29 of Set 9 | schwalmstadt
# Processing Record 30 of Set 9 | azad shahr
# Processing Record 31 of Set 9 | geraldton
# Processing Record 32 of Set 9 | loikaw
# Processing Record 33 of Set 9 | nantucket
# Processing Record 34 of Set 9 | broken hill
# Processing Record 35 of Set 9 | saint-georges
# Processing Record 36 of Set 9 | plettenberg bay
# Processing Record 37 of Set 9 | kaeo
# Processing Record 38 of Set 9 | tarudant
# City not found. Skipping...
# Processing Record 39 of Set 9 | tambura
# Processing Record 40 of Set 9 | green valley
# Processing Record 41 of Set 9 | halifax
# Processing Record 42 of Set 9 | port macquarie
# Processing Record 43 of Set 9 | ornes
# Processing Record 44 of Set 9 | brae
# Processing Record 45 of Set 9 | byron bay
# Processing Record 46 of Set 9 | dhing
# Processing Record 47 of Set 9 | vitim
# Processing Record 48 of Set 9 | reconquista
# Processing Record 49 of Set 9 | eureka
# Processing Record 50 of Set 9 | kaitong
# Processing Record 1 of Set 10 | saint-louis
# Processing Record 2 of Set 10 | nesbyen
# Processing Record 3 of Set 10 | veraval
# Processing Record 4 of Set 10 | busembatia
# Processing Record 5 of Set 10 | trincomalee
# Processing Record 6 of Set 10 | margate
# Processing Record 7 of Set 10 | ngawen
# Processing Record 8 of Set 10 | umzimvubu
# City not found. Skipping...
# Processing Record 9 of Set 10 | ballina
# Processing Record 10 of Set 10 | boa esperanca
# Processing Record 11 of Set 10 | lewisporte
# Processing Record 12 of Set 10 | clyde river
# Processing Record 13 of Set 10 | mezen
# Processing Record 14 of Set 10 | kavieng
# Processing Record 15 of Set 10 | saleaula
# City not found. Skipping...
# Processing Record 16 of Set 10 | karamken
# City not found. Skipping...
# Processing Record 17 of Set 10 | baykit
# Processing Record 18 of Set 10 | nguiu
# City not found. Skipping...
# Processing Record 19 of Set 10 | barentu
# Processing Record 20 of Set 10 | deputatskiy
# Processing Record 21 of Set 10 | ponta delgada
# Processing Record 22 of Set 10 | maragogi
# Processing Record 23 of Set 10 | hamilton
# Processing Record 24 of Set 10 | kununurra
# Processing Record 25 of Set 10 | dublin
# Processing Record 26 of Set 10 | panguna
# Processing Record 27 of Set 10 | umm lajj
# Processing Record 28 of Set 10 | pangai
# Processing Record 29 of Set 10 | terrasini
# Processing Record 30 of Set 10 | mudu
# Processing Record 31 of Set 10 | juye
# Processing Record 32 of Set 10 | hobyo
# Processing Record 33 of Set 10 | russkaya polyana
# Processing Record 34 of Set 10 | dothan
# Processing Record 35 of Set 10 | skjervoy
# Processing Record 36 of Set 10 | viedma
# Processing Record 37 of Set 10 | kommunar
# Processing Record 38 of Set 10 | coolum beach
# Processing Record 39 of Set 10 | xichang
# Processing Record 40 of Set 10 | lyubeshiv
# City not found. Skipping...
# Processing Record 41 of Set 10 | mount gambier
# Processing Record 42 of Set 10 | tekirdag
# Processing Record 43 of Set 10 | arkhipo-osipovka
# Processing Record 44 of Set 10 | bati
# Processing Record 45 of Set 10 | dukat
# Processing Record 46 of Set 10 | laguna
# Processing Record 47 of Set 10 | methoni
# Processing Record 48 of Set 10 | verkhnevilyuysk
# Processing Record 49 of Set 10 | titlagarh
# Processing Record 50 of Set 10 | takoradi
# Processing Record 1 of Set 11 | mosetse
# Processing Record 2 of Set 11 | gambela
# Processing Record 3 of Set 11 | trinidad
# Processing Record 4 of Set 11 | ferzikovo
# Processing Record 5 of Set 11 | christchurch
# Processing Record 6 of Set 11 | buchanan
# Processing Record 7 of Set 11 | palmares do sul
# Processing Record 8 of Set 11 | batagay-alyta
# Processing Record 9 of Set 11 | opuwo
# Processing Record 10 of Set 11 | goundam
# Processing Record 11 of Set 11 | susangerd
# Processing Record 12 of Set 11 | galle
# Processing Record 13 of Set 11 | vestmannaeyjar
# Processing Record 14 of Set 11 | sorland
# Processing Record 15 of Set 11 | mayfield
# Processing Record 16 of Set 11 | phan rang
# City not found. Skipping...
# Processing Record 17 of Set 11 | lukovetskiy
# Processing Record 18 of Set 11 | balikpapan
# Processing Record 19 of Set 11 | sao jose do calcado
# Processing Record 20 of Set 11 | capao da canoa
# Processing Record 21 of Set 11 | iracoubo
# Processing Record 22 of Set 11 | bintulu
# Processing Record 23 of Set 11 | mitsamiouli
# Processing Record 24 of Set 11 | moyale
# Processing Record 25 of Set 11 | codrington
# Processing Record 26 of Set 11 | san andres
# Processing Record 27 of Set 11 | samalaeulu
# City not found. Skipping...
# Processing Record 28 of Set 11 | abonnema
# Processing Record 29 of Set 11 | souillac
# Processing Record 30 of Set 11 | lavrentiya
# Processing Record 31 of Set 11 | ketchikan
# Processing Record 32 of Set 11 | rockport
# Processing Record 33 of Set 11 | sabang
# Processing Record 34 of Set 11 | luang prabang
# Processing Record 35 of Set 11 | crestview
# Processing Record 36 of Set 11 | kachikau
# City not found. Skipping...
# Processing Record 37 of Set 11 | guhagar
# Processing Record 38 of Set 11 | taltal
# Processing Record 39 of Set 11 | indramayu
# Processing Record 40 of Set 11 | deder
# Processing Record 41 of Set 11 | tondi
# Processing Record 42 of Set 11 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 43 of Set 11 | salcedo
# Processing Record 44 of Set 11 | boende
# Processing Record 45 of Set 11 | sao felix do xingu
# Processing Record 46 of Set 11 | linxia
# Processing Record 47 of Set 11 | ishcherskaya
# Processing Record 48 of Set 11 | santa marta
# Processing Record 49 of Set 11 | makakilo city
# Processing Record 50 of Set 11 | emerald
# Processing Record 1 of Set 12 | sistranda
# Processing Record 2 of Set 12 | aykhal
# Processing Record 3 of Set 12 | port lincoln
# Processing Record 4 of Set 12 | ha giang
# Processing Record 5 of Set 12 | saint-augustin
# Processing Record 6 of Set 12 | canico
# Processing Record 7 of Set 12 | bolama
# Processing Record 8 of Set 12 | erzin
# Processing Record 9 of Set 12 | el prat de llobregat
# Processing Record 10 of Set 12 | jiamusi
# Processing Record 11 of Set 12 | bossembele
# City not found. Skipping...
# Processing Record 12 of Set 12 | axim
# Processing Record 13 of Set 12 | ruteng
# Processing Record 14 of Set 12 | martil
# Processing Record 15 of Set 12 | batemans bay
# Processing Record 16 of Set 12 | boyabat
# Processing Record 17 of Set 12 | sal rei
# Processing Record 18 of Set 12 | te anau
# Processing Record 19 of Set 12 | bonito
# Processing Record 20 of Set 12 | la concepcion
# Processing Record 21 of Set 12 | nouakchott
# Processing Record 22 of Set 12 | quzhou
# Processing Record 23 of Set 12 | ouahigouya
# Processing Record 24 of Set 12 | bilma
# Processing Record 25 of Set 12 | jiaocheng
# Processing Record 26 of Set 12 | opotiki
# Processing Record 27 of Set 12 | oyama
# Processing Record 28 of Set 12 | tongchuan
# Processing Record 29 of Set 12 | fare
# Processing Record 30 of Set 12 | maniwaki
# Processing Record 31 of Set 12 | whitchurch-stouffville
# City not found. Skipping...
# Processing Record 32 of Set 12 | finnsnes
# Processing Record 33 of Set 12 | coihaique
# Processing Record 34 of Set 12 | makung
# City not found. Skipping...
# Processing Record 35 of Set 12 | anuradhapura
# Processing Record 36 of Set 12 | kendari
# Processing Record 37 of Set 12 | hofn
# Processing Record 38 of Set 12 | pimentel
# Processing Record 39 of Set 12 | atar
# Processing Record 40 of Set 12 | saint-denis
# Processing Record 41 of Set 12 | mangrol
# Processing Record 42 of Set 12 | qaqortoq
# Processing Record 43 of Set 12 | guarapari
# Processing Record 44 of Set 12 | ostersund
# Processing Record 45 of Set 12 | saint-joseph
# Processing Record 46 of Set 12 | bemidji
# Processing Record 47 of Set 12 | sambava
# Processing Record 48 of Set 12 | challapata
# Processing Record 49 of Set 12 | canberra
# Processing Record 50 of Set 12 | sitka
# Processing Record 1 of Set 13 | nacala
# Processing Record 2 of Set 13 | clonakilty
# Processing Record 3 of Set 13 | tecpan
# Processing Record 4 of Set 13 | tabou
# Processing Record 5 of Set 13 | benguela
# Processing Record 6 of Set 13 | yarada
# Processing Record 7 of Set 13 | vaitape
# Processing Record 8 of Set 13 | elk river
# Processing Record 9 of Set 13 | cairns
# Processing Record 10 of Set 13 | bonthe
# Processing Record 11 of Set 13 | gibara
# Processing Record 12 of Set 13 | waipawa
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Construct cityData dataframe
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0            Bara      NG  10.3744   10.7288    105.03        16          43
# 1      The Valley      AI  18.2170  -63.0578     82.54        61          40
# 2        Cidreira      BR -30.1811  -50.2056     71.82        83          97
# 3          Dikson      RU  73.5069   80.5464      9.59        95         100
# 4    Saint-Pierre      RE -21.3393   55.4781     80.29        69         100
# 5       Jamestown      US  42.0970  -79.2353     39.18        64         100
# 6          Castro      BR -24.7911  -50.0119     75.07        65          95
# 7  Port Elizabeth      ZA -33.9180   25.5701     67.10        82          79
# 8  Saint-Philippe      RE -21.3585   55.7679     80.22        84          46
# 9           Airai      TL  -8.9266  125.4092     59.22        83          97
#
#    Wind Speed Current Description
# 0        0.98    scattered clouds
# 1       19.57    scattered clouds
# 2        9.15     overcast clouds
# 3        4.59     overcast clouds
# 4       19.57     overcast clouds
# 5       11.50     overcast clouds
# 6        5.37     overcast clouds
# 7       11.99       broken clouds
# 8       10.40          light rain
# 9        2.62     overcast clouds

# %%
city_data_df = city_data_df[["City", "Country", "Lat", "Lng", "Max Temp","Humidity","Cloudiness","Wind Speed", "Current Description"]]

# %%
city_data_df.head(15)
# Out:
#                        City Country      Lat       Lng  Max Temp  Humidity  \
# 0                      Bara      NG  10.3744   10.7288    105.03        16
# 1                The Valley      AI  18.2170  -63.0578     82.54        61
# 2                  Cidreira      BR -30.1811  -50.2056     71.82        83
# 3                    Dikson      RU  73.5069   80.5464      9.59        95
# 4              Saint-Pierre      RE -21.3393   55.4781     80.29        69
# 5                 Jamestown      US  42.0970  -79.2353     39.18        64
# 6                    Castro      BR -24.7911  -50.0119     75.07        65
# 7            Port Elizabeth      ZA -33.9180   25.5701     67.10        82
# 8            Saint-Philippe      RE -21.3585   55.7679     80.22        84
# 9                     Airai      TL  -8.9266  125.4092     59.22        83
# 10  Puerto Baquerizo Moreno      EC  -0.9000  -89.6000     79.79        83
# 11                Busselton      AU -33.6500  115.3333     59.49        56
# 12                 Ciulnita      RO  44.5333   27.3500     75.60        33
# 13                Grindavik      IS  63.8424  -22.4338     37.87        93
# 14                  College      US  64.8569 -147.8028     -2.42        70
#
#     Cloudiness  Wind Speed Current Description
# 0           43        0.98    scattered clouds
# 1           40       19.57    scattered clouds
# 2           97        9.15     overcast clouds
# 3          100        4.59     overcast clouds
# 4          100       19.57     overcast clouds
# 5          100       11.50     overcast clouds
# 6           95        5.37     overcast clouds
# 7           79       11.99       broken clouds
# 8           46       10.40          light rain
# 9           97        2.62     overcast clouds
# 10          20       13.80          few clouds
# 11          99        5.26     overcast clouds
# 12           4       15.48           clear sky
# 13          75       28.77       broken clouds
# 14           0        0.00           clear sky

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
