# %% [markdown]
# ## Deliverable 3. Create a Travel Itinerary Map.

# %%
# Dependencies and Setup
import pandas as pd
import requests
import gmaps

# Import API key
from config import g_key

# Configure gmaps
gmaps.configure(api_key=g_key)

# %%
# 1. Read the WeatherPy_vacation.csv into a DataFrame.
clean_hotel_df = pd.read_csv("../Vacation_Search/WeatherPy_vacation.csv")
clean_hotel_df
# Out:
#      City_ID            City Country  Max Temp Current Description      Lat  \
# 0          2        Cidreira      BR     71.82     overcast clouds -30.1811
# 1          6          Castro      BR     75.07     overcast clouds -24.7911
# 2          7  Port Elizabeth      ZA     67.10       broken clouds -33.9180
# 3         11       Busselton      AU     59.49     overcast clouds -33.6500
# 4         12        Ciulnita      RO     75.60           clear sky  44.5333
# ..       ...             ...     ...       ...                 ...      ...
# 201      543      Challapata      BO     53.73       broken clouds -18.9000
# 202      544        Canberra      AU     60.78     overcast clouds -35.2835
# 203      547      Clonakilty      IE     51.10     overcast clouds  51.6231
# 204      548          Tecpan      GT     60.62       broken clouds  14.7623
# 205      554          Cairns      AU     77.07       broken clouds -16.9167
#
#           Lng                     Hotel Name
# 0    -50.2056                  Hotel Castelo
# 1    -50.0119                 CHACARA BAILLY
# 2     25.5701         39 On Nile Guest House
# 3    115.3333        Observatory Guest House
# 4     27.3500                   Hotel Select
# ..        ...                            ...
# 201  -66.7667                  HOSTAL MARIAN
# 202  149.1281               Novotel Canberra
# 203   -8.8706  Inchydoney Island Lodge & Spa
# 204  -90.9947              Villa San Ricardo
# 205  145.7667          Mantra Trilogy Cairns
#
# [206 rows x 8 columns]

# %%
# 2. Using the template add the city name, the country code, the weather description and maximum temperature for the city.
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Current Weather</dt><dd>{Current Description} and {Max Temp} °F</dd>
</dl>
"""

# 3a. Get the data from each row and add it to the formatting template and store the data in a list.
hotel_info = [info_box_template.format(**row) for index, row in clean_hotel_df.iterrows()]

# 3b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = clean_hotel_df[["Lat", "Lng"]]

# %%
# 4a. Add a marker layer for each city to the map.
max_temp = clean_hotel_df["Max Temp"]

fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=max_temp,dissipating=False,
             max_intensity=300, point_radius=4)
marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
fig.add_layer(heat_layer)
fig.add_layer(marker_layer)

# 4b. Display the figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
my_itenary =  clean_hotel_df[clean_hotel_df["Country"] == "AU"]
my_itenary
# Out:
#      City_ID            City Country  Max Temp Current Description      Lat  \
# 3         11       Busselton      AU     59.49     overcast clouds -33.6500
# 13        54          Hobart      AU     64.26    scattered clouds -42.8794
# 23        83       Mount Isa      AU     71.37           clear sky -20.7333
# 27        96          Parkes      AU     63.36     overcast clouds -33.1333
# 56       160       Esperance      AU     60.64    scattered clouds -33.8667
# 67       182     New Norfolk      AU     63.90          few clouds -42.7826
# 73       202       Carnarvon      AU     73.47           clear sky -24.8667
# 77       215         Mareeba      AU     72.45    scattered clouds -17.0000
# 96       265       Ulladulla      AU     63.77       broken clouds -35.3500
# 138      389       Geraldton      AU     63.01    scattered clouds -28.7667
# 141      392     Broken Hill      AU     68.23           clear sky -31.9500
# 146      399  Port Macquarie      AU     63.90    scattered clouds -31.4333
# 147      402       Byron Bay      AU     65.95       broken clouds -28.6500
# 152      415         Ballina      AU     66.02       broken clouds -28.8667
# 155      427       Kununurra      AU     69.78    scattered clouds -15.7667
# 162      441    Coolum Beach      AU     71.11     overcast clouds -26.5333
# 164      443   Mount Gambier      AU     59.16           clear sky -37.8333
# 173      476      Codrington      AU     65.14       broken clouds -38.2667
# 182      498         Emerald      AU     71.35           clear sky -23.5333
# 183      501    Port Lincoln      AU     68.02          few clouds -34.7333
# 190      512    Batemans Bay      AU     65.10       broken clouds -35.7167
# 202      544        Canberra      AU     60.78     overcast clouds -35.2835
# 205      554          Cairns      AU     77.07       broken clouds -16.9167
#
#           Lng                                      Hotel Name
# 3    115.3333                         Observatory Guest House
# 13   147.3294           St Ives Hobart Accommodation Tasmania
# 23   139.5000                       ibis Styles Mt Isa Verona
# 27   148.1833                                   Station Motel
# 56   121.9000                           Hospitality Esperance
# 67   147.0587                 The Shingles Riverside Cottages
# 73   113.6333                           Hospitality Carnarvon
# 77   145.4333                     Trinity Plains Tourist Park
# 96   150.4667                                 Sandpiper Motel
# 138  114.6000                       Broadwater Mariner Resort
# 141  141.4333                            Royal Exchange Hotel
# 146  152.9167                           Rydges Port Macquarie
# 147  153.6167                                 Backpackers Inn
# 152  153.5667  Ramada Hotel & Suites by Wyndham Ballina Byron
# 155  128.7333                                 Hotel Kununurra
# 162  153.1000                             Coolum Beach Resort
# 164  140.7667                                   The Commodore
# 173  141.9667            Codrington Gardens Bed And Breakfast
# 182  148.1667                               The Irish Village
# 183  135.8667                              Port Lincoln Hotel
# 190  150.1833                      Batemans Bay Marina Resort
# 202  149.1281                                Novotel Canberra
# 205  145.7667                           Mantra Trilogy Cairns

# %%
# From the map above pick 4 cities and create a vacation itinerary route to travel between the four cities. 

# 5. Create DataFrames for each city by filtering the 'vacation_df' using the loc method. 
# Hint: The starting and ending city should be the same city.

vacation_start = clean_hotel_df.loc[clean_hotel_df['City'] == 'Esperance']
vacation_end = vacation_start
vacation_stop1 = clean_hotel_df.loc[clean_hotel_df['City'] == 'Busselton']
vacation_stop2 = clean_hotel_df.loc[clean_hotel_df['City'] == 'Geraldton']
vacation_stop3 = clean_hotel_df.loc[clean_hotel_df['City'] == 'Carnarvon']

#print(vacation_start)

#vacation_end

# %%
# 6. Get the latitude-longitude pairs as tuples from each city DataFrame using the to_numpy function and list indexing.
start = tuple(vacation_start[["Lat", "Lng"]].to_numpy()[0])
end = start
stop1 = tuple(vacation_stop1[["Lat", "Lng"]].to_numpy()[0])
stop2 = tuple(vacation_stop2[["Lat", "Lng"]].to_numpy()[0])
stop3 = tuple(vacation_stop3[["Lat", "Lng"]].to_numpy()[0])
#print(start)
#end

# %%
# 7. Create a direction layer map using the start and end latitude-longitude pairs,
# and stop1, stop2, and stop3 as the waypoints. The travel_mode should be "DRIVING", "BICYCLING", or "WALKING".

fig = gmaps.figure()

waypoints = [stop1, stop2,stop3]
directions_layer = gmaps.directions_layer(start, end, waypoints=waypoints, travel_mode='DRIVING')

fig.add_layer(directions_layer)

fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# 8. To create a marker layer map between the four cities.
#  Combine the four city DataFrames into one DataFrame using the concat() function.
itinerary_df = pd.concat([vacation_start,vacation_stop1,vacation_stop2,vacation_stop3],ignore_index=True)
itinerary_df
# Out:
#    City_ID       City Country  Max Temp Current Description      Lat  \
# 0      160  Esperance      AU     60.64    scattered clouds -33.8667
# 1       11  Busselton      AU     59.49     overcast clouds -33.6500
# 2      389  Geraldton      AU     63.01    scattered clouds -28.7667
# 3      202  Carnarvon      AU     73.47           clear sky -24.8667
#
#         Lng                 Hotel Name
# 0  121.9000      Hospitality Esperance
# 1  115.3333    Observatory Guest House
# 2  114.6000  Broadwater Mariner Resort
# 3  113.6333      Hospitality Carnarvon

# %%
# 9 Using the template add city name, the country code, the weather description and maximum temperature for the city. 
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Current Weather</dt><dd>{Current Description} and {Max Temp} °F</dd>
</dl>
"""

# 10a Get the data from each row and add it to the formatting template and store the data in a list.
hotel_info = [info_box_template.format(**row) for index, row in itinerary_df.iterrows()]

# 10b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = itinerary_df[["Lat", "Lng"]]

# %%
# 11a. Add a marker layer for each city to the map.

fig = gmaps.figure()
marker_layer = gmaps.marker_layer(locations,info_box_content=hotel_info)

fig.add_layer(marker_layer)


# 11b. Display the figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
